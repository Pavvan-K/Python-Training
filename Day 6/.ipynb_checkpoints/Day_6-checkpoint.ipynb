# %%
from IPython.display import Image

# %% [markdown]
# ## File Operations:

# %% [markdown]
# #### What is a file?

# %% [markdown]
# * File is a named location on disk to store related information
# * It is used to permanently store data in a non-volatile memory. Since, random access memory (RAM) is volatile which loses its data when computer is turned off, we use files for future use of the data

# %% [markdown]
# * a file operation takes place in the following order.
#     * Open a file
#     * Read or write (perform operation)
#     * Close the file
#     * Delete Or Restore

# %% [markdown]
# * To save the Data in  persistent way

# %%
import os
os.getcwd()
# Out:
# 'E:\\Python\\Training'

# %%
import os

# %%
os.getcwd()
# Out:
# 'F:\\Python Training\\Day 6'

# %%
os.chdir("F:\\Python Training\\Day 6\\MyFiles")

# %%
os.getcwd()
# Out:
# 'F:\\Python Training\\Day 6\\MyFiles'

# %%
os.listdir()
# Out:
# ['Test.txt']

# %%
os.chdir(r"F:\Python Training\Day 6\MyFiles") #'E:\\Python\\Training' to --

# %%
os.getcwd()
# Out:
# 'F:\\Python Training\\Day 6\\MyFiles'

# %% [markdown]
# ### Open

# %% [markdown]
#  Syntax: open(FileName, modeOfOperation)

# %%
f=open("test.txt") # read

# %%
print(f)
# Out:
# <_io.TextIOWrapper name='test.txt' mode='r' encoding='cp1252'>

# %% [markdown]
# #### File Reading:

# %%
print(f.readlines()) # One line

# %%
print(f.readline())
# Out:
# second line

# %%
print(f.readline())
# Out:
# thirdline

# %%
print(f.readlines())
# Out:
# ['FirstLine\n', 'second line\n', 'thirdline\n', 'fourth line']

# %%
for lines in f.readlines():
    print(lines,end="")
# Out:
# FirstLine
# second line
# thirdline
# fourth line

# %% [markdown]
# #### File Appending:

# %%
my_data
# Out:
# ['My InfoMy Info and Appeded InfoMy Info and Appeded Info... Keep on add']

# %%
f.tell() ## To get the cursor position
# Out:
# 46

# %%
f.seek(0) ## to Reset the Curson position to desired index.
# Out:
# 0

# %%
f.close() # to Close the file

# %%
print(f.readline())
# Out:
# FirstLine

# %%
print(f.readline(),end="")
# Out:
# second line

# %% [markdown]
# #### File Writing:

# %%
f1 = open('abc.txt','w')
f1.write("""I am Learning Files I/O operations in Python
Second Line
Third Line""")
# f1.close()
# Out:
# 67

# %%
f1 = open('abc2.txt','w')

# %%
f1.write("Something")
# Out:
# 9

# %%
f1.close()

# %%
f1 = open('abc.txt')
f1.close()

# %%
f1 = open('abc.txt')
f1.read(2)
# Out:
# 'I '

# %%
f1.read(2)
# Out:
# ' L'

# %%
f.tell()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-94-322ae27c0b94> in <module>()
# ----> 1 f.tell()
#
# ValueError: I/O operation on closed file.

# %%
f1.seek(0)
# Out:
# 0

# %%
f1 = open('abc.text','w')

f1.write("THis is I wrote!")

f1.write("This is my secondline")
f1.close()

# %%
f1.close()

# %% [markdown]
# #### File Overwriting:

# %%
f1 = open('abc.text','w')
f1.close()

# %%
f1 = open('abc.text','w')
f1.write("Thirdline")
f1.close()

# %%
f1 = open('abc.text','w')
f1.write("Thirdline2")     
f1.close()

# %% [markdown]
# After running above cell you can observe that content gets overwrited.

# %%
f1 = open('abc.text','a')
f1.write("Thirdline2")
# Out:
# 10

# %%
f1.close()

# %%
f.close()

# %% [markdown]
# #### Copying Files:

# %%
f1 = open("Test.txt")
f2 = open("abc.text",'a')

for lines in f1.readlines():
    print(lines)
    f2.write(lines)

f2.close()
f1.close()
# Out:
# FirstLine
#
# second line
#
# thirdline
#
# fourth line

# %%
f=open('test.txt')
for data in f.readlines():
    print(data)
# Out:
# firstline
#
# secondline
#
# thirdline
#
# fourthline
#
# fifthline

# %%
f1 = open('abc.text','a')
f=open("test.txt") # read
for data in f.readlines():
    f1.write(data)

# %%
f1.close()
f.close()

# %% [markdown]
# #### Creating Duplicate Image using File Operations `wb` and `rb` mode:

# %%
f1 = open("F:\Images\personal\Pavan.jpg",'rb')

# f1.read()

f2 = open("F:\Images\personal\Pavan_Duplicate.jpg",'wb')

for byte in f1.readlines():
    f2.write(byte)

f2.close()
f1.close()

# %% [markdown]
# #### File Opeartions using `With` Keyword:

# %% [markdown]
# * In this Method we can use with Keyword
# * The with statement simplifies exception handling by encapsulating common
# preparation and cleanup tasks.
# * In addition, it will automatically close the file. The with statement provides
# a way for ensuring that a clean-up is always used.

# %% [markdown]
# #### Appending:

# %%
with open("abc.txt",'a') as f:
    f.write("My Info and Appeded Info... Keep on add")

# %% [markdown]
# #### Writing:

# %%
with open("abc2.txt",'w') as f:
    f.write("I just wrote this infomration.")

# %% [markdown]
# #### Reading:

# %%
with open("abc.txt",'r') as f:
    my_data = f.readlines()

# %% [markdown]
# ### Different Modes of Operation

# %%
Image(url= "http://1p9tpk1c3jcx2qvybv1oynit.wpengine.netdna-cdn.com/wp-content/uploads/2011/09/python_file3.png")
# Out:
# <img src="http://1p9tpk1c3jcx2qvybv1oynit.wpengine.netdna-cdn.com/wp-content/uploads/2011/09/python_file3.png"/>

# %%
Image(url="https://www.researchgate.net/publication/303337342/figure/fig6/AS:372577043271686@1465840697604/Pythons-file-access-modes.png")
